# %% [markdown]
# # Packaging
# Dave Forgac
#
# http://daveops.com/pycon2017
#
# tl;dr
# start with a CookieCutter.
#
# module
# - saved pythong code
#
# import package
# - namespace / dir
#
# distribrion package
# - shareable, installable
#
# Source distribution
# - sdist
# - extensions too
# - built on install
#
# Built Distribution
# - egg
# - Wheel
# - prebuilt
#
# Wheel
# - universal (only python code, 2/3)
# - pure python (specific to 2 or 3)
# - platform wheel
#
# history
# - copy/replace
# - PyPA (python packaging authority)
# - PuPUG (User Guide https://packaging.pythong.org )
#
# $ cookiecutter package-name
#
# pep440 - version names
#
# install_requires=[''] - similiar to requirements.txt
#
# entry_points - wraps the console
#
# classifiers - not really used right now
#
# setup.py -> license
#
# Tests
# - ./tests
# - tox.ini
#
# Docs
# - ./docs
#
# CI
# - .travis.yml
#
# requirements.txt
# - used for developers,
# - pip tools
#
# -1) cookiecutter
# 0) git commit #0
# 1) github
# 2) https://travis-ci.org/
# 3) read the docs / github pages
# 4) pypi / testpypi
#
# virtualenv
# pew
# virtualenvwrapper
#
# pip install wheel
# pip install twine
#
# ./setup.py sdist
# ./setup.py bdist_wheel
# make dist
#
# twine upload dist/*
#
# pip install package-name
#
# develop mode
# - ./setup.py develop
# - pip install -e
#
# rinse and repeat
#
# Versions
# - bumpversion
# - versioneer
#
# recap
# - don't go it alone
# - use the tools
# - share your code
