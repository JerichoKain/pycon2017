# %% [markdown]
# # A gentle introduction to deep learning
# Michelle Fullwood
#
# (deep) feed forward neural networks
#
# linear regression from scratch
#  - predict the individual price of houses
#  - floor area
#  - number of rooms
#  - distance from public transit
#
# x -> y
# model
#  - multiply each feature by weight to fine intercept
#  - cost function (are we good or bad with the fit)
#   - sum of squares
#  - optimized by gradient descent
#
#
# Tensorflow
# inputs -> placehodlers
# parameters -> variables
# operations
# cost - sum of squares
# optimization
#
# training -> sessions
#
# nueral graph -> forward propogation (sieve)
#              -> backpropogation
#              -> update variable
#
# train in session
#
#
# logistic regression
#  - (dressed up linear regression
#  - not very good since there is not a good way to put a line through a complete field of points
#  -
#
# why use deep (3 layers)
#  - more powerful
#  - less prone to over fitness
#  - learns hierarchical representations (end to end learning)
#
# without enoug data -> overfitting
# combat this with regularization (L2)
#
#
# other training with hidden layers
# dropout train
#  - throw out half of the neurons
#  - "averaging" all the different models
#  - reinforces useful features
#  - stops conspiracy (can't false positive when the partner may drop out)
#  - logits get doubled if they are not dropped
#  - remember to train more when using dropout (more models to consider)
#
#  convolution networks
#  recurring neural networks
#
#  besides tensor...
#  pytorch
#  caffe
#  mxnet
#  dynet
#  ...
#
# keras is a higher level than tensorflow
#
# michelleful.github.io/pycon2017
